# %%
import sys
sys.path.append('../scripts')  # Ensures it finds your scripts folder

from data_loader import load_and_merge_data
from data_preparation import prepare_data

# Load and prepare the data
merged_df = load_and_merge_data('../data')
prepared_df = prepare_data(merged_df)

# Display result
prepared_df.tail()
# Out:
# /home/dhanya/Documents/pair_trading/notebooks/../scripts/data_preparation.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
#              TECHM  NUCLEUS  COFORGE  3IINFOLTD  INTELLECT  DATAMATICS  \
# Date
# 2025-07-08  1635.4   1161.0   1949.6      24.06     1166.1      669.05
# 2025-07-09  1614.8   1169.7   1931.3      24.09     1180.1      667.30
# 2025-07-10  1600.1   1181.4   1887.7      24.05     1147.3      673.10
# 2025-07-11  1602.5   1159.1   1867.8      23.80     1152.0      732.15
# 2025-07-14  1576.7   1146.5   1875.0      23.53     1172.2      735.95
#
#               OFSS  SASKEN  HCLTECH  ZENSARTECH  ...     TCS  TATAELXSI  \
# Date                                             ...
# 2025-07-08  9006.5  1470.4   1708.1      844.95  ...  3406.2     6171.5
# 2025-07-09  8938.5  1455.2   1674.0      849.25  ...  3383.8     6152.0
# 2025-07-10  8777.0  1456.6   1663.7      846.50  ...  3382.0     6137.5
# 2025-07-11  8636.0  1440.4   1638.3      818.70  ...  3266.0     6066.0
# 2025-07-14  8733.5  1421.6   1619.8      808.65  ...  3222.7     6179.0
#
#             AURIONPRO   TANLA  XCHANGING  CYIENT  RAMCOSYS    LTTS  \
# Date
# 2025-07-08     1606.5  635.95      99.56  1289.9    383.80  4336.0
# 2025-07-09     1621.5  638.00      99.82  1291.2    382.95  4314.4
# 2025-07-10     1614.6  636.60      99.51  1293.9    393.45  4349.2
# 2025-07-11     1611.0  632.10      95.83  1271.3    386.80  4410.5
# 2025-07-14     1640.3  634.95      96.25  1293.8    386.20  4343.2
#
#             SONATSOFTW    INFY
# Date
# 2025-07-08      439.95  1638.7
# 2025-07-09      433.65  1633.7
# 2025-07-10      430.30  1615.8
# 2025-07-11      430.05  1594.9
# 2025-07-14      432.90  1570.3
#
# [5 rows x 28 columns]
