# %%
import sys
sys.path.append('../scripts')

from data_loader import load_and_merge_data
from data_preparation import prepare_data
from eda_utils import plot_stock_prices, plot_correlation_matrix

# Load & prepare
df = load_and_merge_data('../data')
prepared_df = prepare_data(df)

# Visualize
plot_stock_prices(prepared_df, prepared_df.columns[:5])  # first 5 stocks
plot_correlation_matrix(prepared_df)
# Out:
# /home/dhanya/Documents/pair_trading/notebooks/../scripts/data_preparation.py:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
