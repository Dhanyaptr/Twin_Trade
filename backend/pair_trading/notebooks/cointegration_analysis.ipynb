# %%
from scripts.cointegration_utils import (
    find_cointegrated_pairs,
    get_hedge_ratio,
    calculate_spread,
    calculate_rolling_mean_std
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from scripts.cointegration_utils import (
#       2     find_cointegrated_pairs,
#       3     get_hedge_ratio,
#       4     calculate_spread,
#       5     calculate_rolling_mean_std
#       6 )
#
# ImportError: cannot import name 'get_hedge_ratio' from 'scripts.cointegration_utils' (/home/dhanya/Documents/pair_trading/scripts/cointegration_utils.py)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rolling_mean, rolling_std = calculate_rolling_stats(spread, window=30)
#
# NameError: name 'calculate_rolling_stats' is not defined
